# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Felicia Lazu**
# Student

# %% [markdown]
# *I am interested in Data Science because I realize it is an extremely useful skill to have in this current age of modern technology. I know that data can provide incredible insights into various areas of life, business, economy and so on - therefore, there is a high demand for professionals who are capable of processing and interpeting said data.*

# %% [markdown]
# ### The code in cell 5 should calculate and display a simple addition command.

# %%
25+57
# Out:
# 82

# %% [markdown]
# ***
# Final Comments:
# ***
# * This final assignment required making a Jupyter Notebook
# * It summarizes some main skills we learned during the course
# * It is a nice wrap-up to the course!
# I am looking forward to learning even more new skills thanks to the <a href="http://coursera.org" target="_blank">Coursera platform</a>.
